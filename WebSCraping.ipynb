# %%
from selenium import webdriver
import bs4 as bs
import pandas as pd

# %%
# base_url = "https://www.artsy.net/artist/salman-toor/auction-results?categories%5B0%5D=Painting&sizes%5B0%5D=SMALL&sizes%5B1%5D=MEDIUM&sizes%5B2%5D=LARGE"
base_url = 'https://www.artsy.net/'

# %%
driver = webdriver.Chrome()

# %%
driver.get(base_url)

# %%
# login
login_button_xpath = '//*[@id="react-root"]/div/div/div[1]/div/header/div/nav/div[1]/a[2]/div'

login_button = driver.find_element_by_xpath(login_button_xpath)
login_button.click()

# %%
# credentials
from selenium.webdriver.common.keys import Keys
username_ = 'dhvanigolani2000@gmail.com'
password_ = ''

username_box_xpath = '//*[@id="main"]/div/div/div/div/form/div[1]/div[2]/input'
username_box = driver.find_element_by_xpath(username_box_xpath)
username_box.send_keys(username_)

password_box_xpath = '//*[@id="main"]/div/div/div/div/form/div[3]/div/div[2]/input'
password_box = driver.find_element_by_xpath(password_box_xpath)
password_box.send_keys(password_)
# password_box.submit() 
login_xpath = '//*[@id="main"]/div/div/div/div/form/button/div'
login = driver.find_element_by_xpath(login_xpath)
login.click()

# %%
url = 'https://www.artsy.net/artist/salman-toor/auction-results?categories%5B0%5D=Painting&sizes%5B0%5D=SMALL&sizes%5B1%5D=MEDIUM&sizes%5B2%5D=LARGE'
driver.get(url)

# %%
painting_name_classname = 'Box-sc-15se88d-0 Text-sc-18gcpao-0  ldlHGe'
painting_type_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/*'
from selenium.webdriver.common.by import By

paintings_dataframe = pd.DataFrame(columns=['Painting_name','Painting_type','Painting_sale_date','Artist_name','Sale_price(euros)','Sale_price(dollars)','Realized price','percent_change'])

# Painting_name = []
for i in (driver.find_elements(By.XPATH, painting_type_xpath)):
    lst_data=list(i.text.split("\n"))
#     print(lst_data)
    if (' ' not in lst_data) and (len(lst_data)==8):
#         paintings_dataframe.fillna('Null')
        paintings_dataframe.loc[len(paintings_dataframe)] = lst_data

paintings_dataframe
# Out:
#                                        Painting_name  \
# 0                          Immigrant Gathering, 2016
# 1  Salman Toor 薩爾曼 · 圖爾 | Man with Tote Bag and L...
# 2                 Man with Tote Bag and Laptop, 2018
# 3                                Bendiyan Farm, 2016
# 4                         Three Men with Trays, 2018
# 5                                      Decent Couple
# 6                                   Cloudy Day, 2017
#
#                 Painting_type Painting_sale_date Artist_name  \
# 0               oil on canvas       Oct 13, 2022    Phillips
# 1                oil on panel        Oct 7, 2022   Sotheby's
# 2                oil on panel        Oct 7, 2022   Sotheby's
# 3               oil on canvas        Jul 1, 2022  Christie's
# 4                oil on panel       Jun 30, 2022    Phillips
# 5  oil and graphite on canvas       Jun 30, 2022   Sotheby's
# 6               oil on canvas       Jun 29, 2022    Phillips
#
# ...

# %%
painting_type_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/*'
painting_type = driver.find_element_by_xpath(painting_type_xpath).text
print(type(painting_type))
print(len(painting_type))
p=list(painting_type.split("\n"))
print(p)

paintings_dataframe = pd.DataFrame(columns=['Painting_name','Painting_type','Painting_sale_date','Artist_name','Sale_price(euros)','Sale_price(dollars)','Realized price','percent_change'])
paintings_dataframe.loc[len(paintings_dataframe)] = p

paintings_dataframe
# Out:
# <class 'str'>
# 116
# ['Man with Tote Bag and Laptop, 2018', 'oil on panel', 'Oct 7, 2022', "Sotheby's", 'HK$2,772,000', 'US$353,139', 'Realized price', '16% est']
#                         Painting_name Painting_type Painting_sale_date  \
# 0  Man with Tote Bag and Laptop, 2018  oil on panel        Oct 7, 2022
#
#   Artist_name Sale_price(euros) Sale_price(dollars)  Realized price  \
# 0   Sotheby's      HK$2,772,000          US$353,139  Realized price
#
#   percent_change
# 0        16% est

# %%
auction_sale_date_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/button[1]/div/div[3]/div[1]'
auction_sale_date = driver.find_element_by_xpath(auction_sale_date_xpath).text
print(auction_sale_date)
# Out:
# Oct 7, 2022

# %%
artist_name_xpath = '//div[@class="Box-sc-15se88d-0 Text-sc-18gcpao-0  ldlHGe"]'
atrist_name = driver.find_elements_by_xpath(artist_name_xpath)
for a in atrist_name:
    print(a.text)
# Out:
# Man with Tote Bag and Laptop, 2018
# Oct 7, 2022
# HK$2,772,000
# The Picnic, 2014
# Sep 29, 2022
# US$403,200
# Driver and Maid, 2013
# Sep 29, 2022
# US$94,500
# Bendiyan Farm, 2016
# Jul 1, 2022
# £478,800
# Three Men with Trays, 2018
# Jun 30, 2022
# £315,000
# Decent Couple
# Jun 30, 2022
# £119,700
# Alexandra, the Boys, City Lights
# Jun 30, 2022
# £126,300
# Cloudy Day, 2017
# Jun 29, 2022
# £504,000
# Mother, 2015
# May 19, 2022
# US$60,480
# Untitled, 2014
# May 13, 2022
# US$819,000

# %%
sale_price_euros_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/button[3]/div/div[4]/div[1]/div[1]/div[1]'
sale_price_euros = driver.find_element_by_xpath(sale_price_euros_xpath).text
print(sale_price_euros)
# Out:
# US$94,500

# %%
#Page2
next_button_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/nav/a'
next_button = driver.find_element_by_xpath(next_button_xpath)
next_button.click()

# %%
for i in (driver.find_elements(By.XPATH, painting_type_xpath)):
    lst_data=list(i.text.split("\n"))
#     print(lst_data)
    if (' ' not in lst_data) and (len(lst_data)==8):
#         paintings_dataframe.fillna('Null')
        paintings_dataframe.loc[len(paintings_dataframe)] = lst_data

paintings_dataframe
# Out:
#                          Painting_name               Painting_type  \
# 0   Man with Tote Bag and Laptop, 2018                oil on panel
# 1                  Bendiyan Farm, 2016               oil on canvas
# 2           Three Men with Trays, 2018                oil on panel
# 3                        Decent Couple  oil and graphite on canvas
# 4                     Cloudy Day, 2017               oil on canvas
# 5                       Untitled, 2012               oil on canvas
# 6             The Rooftop Singer, 2017               oil on canvas
# 7              Itinerant Vagrant, 2018                oil on panel
# 8          Floating Bookshelf II, 2018                oil on panel
# 9        East Village Iqbal Bano, 2018                oil on panel
# 10       East Village Iqbal Bano, 2018                oil on panel
# 11           Upper Middle Class Family                oil on panel
#
#    Painting_sale_date   Artist_name Sale_price(euros) Sale_price(dollars)  \
# ...

# %%
#Page3
next_button_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/nav/a[2]'
next_button = driver.find_element_by_xpath(next_button_xpath)
next_button.click()
for i in (driver.find_elements(By.XPATH, painting_type_xpath)):
    lst_data=list(i.text.split("\n"))
#     print(lst_data)
    if (' ' not in lst_data) and (len(lst_data)==8):
#         paintings_dataframe.fillna('Null')
        paintings_dataframe.loc[len(paintings_dataframe)] = lst_data

paintings_dataframe
# Out:
#                          Painting_name               Painting_type  \
# 0   Man with Tote Bag and Laptop, 2018                oil on panel
# 1                  Bendiyan Farm, 2016               oil on canvas
# 2           Three Men with Trays, 2018                oil on panel
# 3                        Decent Couple  oil and graphite on canvas
# 4                     Cloudy Day, 2017               oil on canvas
# 5                       Untitled, 2012               oil on canvas
# 6             The Rooftop Singer, 2017               oil on canvas
# 7              Itinerant Vagrant, 2018                oil on panel
# 8          Floating Bookshelf II, 2018                oil on panel
# 9        East Village Iqbal Bano, 2018                oil on panel
# 10       East Village Iqbal Bano, 2018                oil on panel
# 11           Upper Middle Class Family                oil on panel
# 12                      Untitled, 2012               oil on canvas
# ...

# %%
#Page4
next_button_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/nav/a[2]'
next_button = driver.find_element_by_xpath(next_button_xpath)
next_button.click()
for i in (driver.find_elements(By.XPATH, painting_type_xpath)):
    lst_data=list(i.text.split("\n"))
#     print(lst_data)
    if (' ' not in lst_data) and (len(lst_data)==8):
#         paintings_dataframe.fillna('Null')
        paintings_dataframe.loc[len(paintings_dataframe)] = lst_data

paintings_dataframe
# Out:
#                          Painting_name               Painting_type  \
# 0   Man with Tote Bag and Laptop, 2018                oil on panel
# 1                  Bendiyan Farm, 2016               oil on canvas
# 2           Three Men with Trays, 2018                oil on panel
# 3                        Decent Couple  oil and graphite on canvas
# 4                     Cloudy Day, 2017               oil on canvas
# 5                       Untitled, 2012               oil on canvas
# 6             The Rooftop Singer, 2017               oil on canvas
# 7              Itinerant Vagrant, 2018                oil on panel
# 8          Floating Bookshelf II, 2018                oil on panel
# 9        East Village Iqbal Bano, 2018                oil on panel
# 10       East Village Iqbal Bano, 2018                oil on panel
# 11           Upper Middle Class Family                oil on panel
# 12                      Untitled, 2012               oil on canvas
# ...

# %%
#Page5
next_button_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/nav/a[2]'
next_button = driver.find_element_by_xpath(next_button_xpath)
next_button.click()
for i in (driver.find_elements(By.XPATH, painting_type_xpath)):
    lst_data=list(i.text.split("\n"))
#     print(lst_data)
    if (' ' not in lst_data) and (len(lst_data)==8):
#         paintings_dataframe.fillna('Null')
        paintings_dataframe.loc[len(paintings_dataframe)] = lst_data

paintings_dataframe
# Out:
#                          Painting_name               Painting_type  \
# 0   Man with Tote Bag and Laptop, 2018                oil on panel
# 1                  Bendiyan Farm, 2016               oil on canvas
# 2           Three Men with Trays, 2018                oil on panel
# 3                        Decent Couple  oil and graphite on canvas
# 4                     Cloudy Day, 2017               oil on canvas
# 5                       Untitled, 2012               oil on canvas
# 6             The Rooftop Singer, 2017               oil on canvas
# 7              Itinerant Vagrant, 2018                oil on panel
# 8          Floating Bookshelf II, 2018                oil on panel
# 9        East Village Iqbal Bano, 2018                oil on panel
# 10       East Village Iqbal Bano, 2018                oil on panel
# 11           Upper Middle Class Family                oil on panel
# 12                      Untitled, 2012               oil on canvas
# ...

# %%
#Page6
next_button_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/nav/a[2]'
next_button = driver.find_element_by_xpath(next_button_xpath)
next_button.click()
for i in (driver.find_elements(By.XPATH, painting_type_xpath)):
    lst_data=list(i.text.split("\n"))
#     print(lst_data)
    if (' ' not in lst_data) and (len(lst_data)==8):
#         paintings_dataframe.fillna('Null')
        paintings_dataframe.loc[len(paintings_dataframe)] = lst_data

paintings_dataframe
# Out:
#                              Painting_name               Painting_type  \
# 0       Man with Tote Bag and Laptop, 2018                oil on panel
# 1                      Bendiyan Farm, 2016               oil on canvas
# 2               Three Men with Trays, 2018                oil on panel
# 3                            Decent Couple  oil and graphite on canvas
# 4                         Cloudy Day, 2017               oil on canvas
# 5                           Untitled, 2012               oil on canvas
# 6                 The Rooftop Singer, 2017               oil on canvas
# 7                  Itinerant Vagrant, 2018                oil on panel
# 8              Floating Bookshelf II, 2018                oil on panel
# 9            East Village Iqbal Bano, 2018                oil on panel
# 10           East Village Iqbal Bano, 2018                oil on panel
# 11               Upper Middle Class Family                oil on panel
# ...

# %%
paintings_dataframe.rename(columns = {'Artist_name':'Auction_name'}, inplace = True)
paintings_dataframe
# Out:
#                              Painting_name               Painting_type  \
# 0       Man with Tote Bag and Laptop, 2018                oil on panel
# 1                      Bendiyan Farm, 2016               oil on canvas
# 2               Three Men with Trays, 2018                oil on panel
# 3                            Decent Couple  oil and graphite on canvas
# 4                         Cloudy Day, 2017               oil on canvas
# 5                           Untitled, 2012               oil on canvas
# 6                 The Rooftop Singer, 2017               oil on canvas
# 7                  Itinerant Vagrant, 2018                oil on panel
# 8              Floating Bookshelf II, 2018                oil on panel
# 9            East Village Iqbal Bano, 2018                oil on panel
# 10           East Village Iqbal Bano, 2018                oil on panel
# 11               Upper Middle Class Family                oil on panel
# ...

# %%
paintings_dataframe.assign(Artist_Name='Salman Toor')
# Out:
#                              Painting_name               Painting_type  \
# 0       Man with Tote Bag and Laptop, 2018                oil on panel
# 1                      Bendiyan Farm, 2016               oil on canvas
# 2               Three Men with Trays, 2018                oil on panel
# 3                            Decent Couple  oil and graphite on canvas
# 4                         Cloudy Day, 2017               oil on canvas
# 5                           Untitled, 2012               oil on canvas
# 6                 The Rooftop Singer, 2017               oil on canvas
# 7                  Itinerant Vagrant, 2018                oil on panel
# 8              Floating Bookshelf II, 2018                oil on panel
# 9            East Village Iqbal Bano, 2018                oil on panel
# 10           East Village Iqbal Bano, 2018                oil on panel
# 11               Upper Middle Class Family                oil on panel
# ...

# %%
paintingdf = pd.DataFrame(columns=['Painting_name','Painting_type','Painting_sale_date','Auction_name','Sale_price(euros)','Sale_price(dollars)','Realized price','percent_change','Painting_size'])
painting_type_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/*'
painting_size_xpath1='//div[@class="Box-sc-15se88d-0 Text-sc-18gcpao-0  buodgj"]'
# //*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/div[3]/div/div[2]/div/text()[2]
# Painting_name = []
for i in (driver.find_elements(By.XPATH, painting_type_xpath)):
    lst_data=list(i.text.split("\n"))
    if (' ' not in lst_data) and (len(lst_data)==8):
        p_size=driver.find_element(By.PARTIAL_LINK_TEXT, "cm")
#         lst_data1=i1.text.split("\n")
#         res = [i for i in lst_data1 if 'cm' in i]
#         if res!=[ ]:
        lst_data.append(p_size)  
        paintingdf.loc[len(paintings_dataframe)] = lst_data

paintingdf
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-93-4a516822eec3> in <module>
#       7     lst_data=list(i.text.split("\n"))
#       8     if (' ' not in lst_data) and (len(lst_data)==8):
# ----> 9         p_size=driver.find_element(By.PARTIAL_LINK_TEXT, "cm")
#      10 #         lst_data1=i1.text.split("\n")
#      11 #         res = [i for i in lst_data1 if 'cm' in i]
#
# D:\Anaconda\envs\domain\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# D:\Anaconda\envs\domain\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
painting_type_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/*'

# %%
# driver.find_element(By.PARTIAL_LINK_TEXT, "72.4 x 60.3 cm")

# %%
# reveal_more_button_xpath = '//*[@id="main"]/div/div/div/div[4]/div[7]/div[2]/div[3]/div[2]/button[2]/div/div[4]/div[2]'
reveal_more_button = driver.find_elements_by_xpath("//button[@class='Clickable-sc-10cr82y-0 fvrqBk']")
for button in reveal_more_button:
    button.click()

# %%
painting_size_xpath='//div[@class="Box-sc-15se88d-0 Text-sc-18gcpao-0  buodgj"]'
for i in (driver.find_elements(By.XPATH, painting_size_xpath)):
    lst_data=list(i.text.split("\n"))
    res = [i for i in lst_data if 'cm' in i]
    if res!=[ ]:
        print(res)
# Out:
# ['122 x 81.5 cm (48 x 32 1/8 in.)']
# ['91.4 by 60.9 cm. 36 by 24 in.']

# %%
painting_size_xpath='//div[@class="Box-sc-15se88d-0 Text-sc-18gcpao-0  buodgj"]'
for i in (driver.find_elements(By.XPATH, painting_size_xpath)):
    lst_data=list(i.text.split("\n"))
    res = [i for i in lst_data if '–' in i]
    if res!=[ ]:
        print(res)
# Out:
# ['HK$2,000,000–HK$2,800,000']
# ['US$200,000–US$300,000']
# ['US$60,000–US$80,000']
# ['£120,000–£180,000']
# ['£250,000–£350,000']
# ['£60,000–£80,000']
# ['£150,000–£200,000']
# ['US$50,000–US$70,000']
# ['US$180,000–US$250,000']
